# %% [markdown]
# (advanced-model)=
# # Some more advanced oemof-solph model features

# %% [markdown]
# Here will follow a tutorial going more in depth into things like MILP, non-convex and investment optimization.
